# %% [markdown]
# # EECS 649: Introduction to Artificial Intelligence
#
# ## GroupProject 1: Winealysis
#
# Deliverables:
#
# > ProgramCode
#
# > PowerPoint
#
# > YouTube Video
#
#
# The used dataset is obtained from:
# https://www.kaggle.com/zynicide/wine-reviews
#
# This notebook contains the first steps to find a reasonable approach to the problem and shows the results of the explarationary data analysis as well as the final results and conclusions.

# %% [markdown]
# Setting up EDA:

# %%
#Doing all necessary imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
#EDA
data = pd.read_csv('../data/_raw/winemag-data-130k-v2.csv')
data = data.drop(columns=['Unnamed: 0'])
data = data.drop(columns=['taster_twitter_handle'])

print(data)
print(data.shape)
print(data.columns)

print(data.price.value_counts())
# Out:
#             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
#data.price.hist(bins=50)

data.loc[(data["price"] < 100)].hist()

print(data.points.value_counts())

#cor = data.corr() 
#sns.heatmap(cor, square = True) #Plot the correlation as heat map
# Out:
# 88     17207
# 87     16933
# 90     15410
# 86     12600
# 89     12226
# 91     11359
# 92      9613
# 85      9530
# 93      6489
# 84      6480
# 94      3758
# 83      3025
# 82      1836
# 95      1535
# 81       692
# 96       523
# 80       397
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %% [markdown]
# ### Approach:
#
# ##### NeuralNetwork
# Drop first columns as useless
#
# Drop WineName
#
# Transform [Country, designation, province, region1 & 2, tastername, winery, variety] to one-hot-encodings
#
# Map points and price to the range 0 to 1. (Take into account that points only were awarded from 80 to 100 max.)
#
# Create dictionary from the description and convert description to sparse-matrix.
#
# ##### 2nd model: R-logistic regression? // linear regression

# %% [markdown]
# # Conclusion
